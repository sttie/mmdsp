# %%
import librosa
import matplotlib.pyplot as plt
from scipy import signal
import scipy
import soundfile as sf
import numpy as np

# %%
f0 = 130.82
fd = 16000
note_duration = 3 # sec
note_delay_size = int(0.0000625 * fd)

# %%
def generate(algo, N):
    if algo == "normal":
        return np.random.normal(0, 1, N)
    elif algo == "uniform":
        return np.random.uniform(-1, 1, N)

# %%
def karplus_strong(fd, fs, algo, attenuation, alpha):
    N = int(fd / fs - 1/2)
    note_size = fd * note_duration
    
    y = np.zeros(note_size)
    y[-1] = 0
    
    y[0:N] = generate(algo, N)
    for n in range(N, note_size):
        if alpha is None:
            y[n] = attenuation * 0.5 * (y[n - N] + y[n - N - 1])
        else:
            y[n] = attenuation * 0.5 * ((1 - alpha) * y[n - N] + alpha * y[n - N - 1])

    return y

# %%
def get_chord(fd, f0, notes, algo, attenuation, alpha):
    note_size = fd * note_duration
    chord_size = int((notes.size - 1) + note_size)
    chord = np.zeros((notes.size, chord_size))

    for i in range(notes.size):
        fk = f0 * 2 ** (notes[i] / 12)
        chord[
            i, 
            i * note_delay_size : chord_size - (notes.size - 1 - i) *  note_delay_size
        ] = karplus_strong(fd, fk, algo, attenuation, alpha)[-note_size:]
                

    return chord

# %% [markdown]
# ## Аккорды с разными методами случайной генерации

# %%
chord = get_chord(fd, f0, np.array([2, 5, 6]), "uniform", 1, None)
sound = np.sum(chord, axis=0)
sf.write('chord-default-uniform.wav', sound, fd)

# %%
chord = get_chord(fd, f0, np.array([2, 5, 6]), "normal", 1, None)
sound = np.sum(chord, axis=0)
sf.write('chord-default-normal.wav', sound, fd)

# %% [markdown]
# ### Вывод
#
# Равномерное распределение дает более качественное звучание, чем нормальное

# %% [markdown]
# ## Аккорды с разным коээфициентом затухания

# %%
chord = get_chord(fd, f0, np.array([3, 2, 10]), "uniform", 1, None)
save_chord(chord, "chord-attenuation-1.wav")
# Out:
# write to chord-attenuation-1.wav

# %%
chord = get_chord(fd, f0, np.array([3, 2, 10]), "uniform", 0.1, None)
save_chord(chord, "chord-attenuation-0.1.wav")
# Out:
# write to chord-attenuation-0.1.wav

# %%
chord = get_chord(fd, f0, np.array([1, 1, 1]), "uniform", 0.7, None)
save_chord(chord, "chord-attenuation-0.7.wav")
# Out:
# write to chord-attenuation-0.7.wav
